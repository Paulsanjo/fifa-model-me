# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("wales_sum_cleaned.csv")
df
# Out:
#            Date  Day            Comp           Round    Venue Result  \
# 0    23-03-2018  Fri  Friendlies (M)  Friendlies (M)     Home  W 2–0
# 1    23-03-2018  Fri  Friendlies (M)  Friendlies (M)     Home  W 2–0
# 2    23-03-2018  Fri  Friendlies (M)  Friendlies (M)     Home  W 2–0
# 3    23-03-2018  Fri  Friendlies (M)  Friendlies (M)     Home  W 2–0
# 4    23-03-2018  Fri  Friendlies (M)  Friendlies (M)     Home  W 2–0
# ..          ...  ...             ...             ...      ...    ...
# 778  22-11-2022  Tue       World Cup     Group stage  Neutral  L 1–2
# 779  22-11-2022  Tue       World Cup     Group stage  Neutral  L 1–2
# 780  22-11-2022  Tue       World Cup     Group stage  Neutral  L 1–2
# 781  22-11-2022  Tue       World Cup     Group stage  Neutral  L 1–2
# 782  22-11-2022  Tue       World Cup     Group stage  Neutral  L 1–2
#
#             Squad         Opponent Start                                  Pos  \
# ...

# %%
data=pd.read_csv("wales_def_cleaned.csv")
data
# Out:
#            Date Defensive Day  Defensive Comp Defensive Round Defensive Venue  \
# 0    28-05-2018           Mon  Friendlies (M)  Friendlies (M)            Away
# 1    28-05-2018           Mon  Friendlies (M)  Friendlies (M)            Away
# 2    28-05-2018           Mon  Friendlies (M)  Friendlies (M)            Away
# 3    28-05-2018           Mon  Friendlies (M)  Friendlies (M)            Away
# 4    28-05-2018           Mon  Friendlies (M)  Friendlies (M)            Away
# ..          ...           ...             ...             ...             ...
# 695  25-11-2022           Fri       World Cup     Group stage         Neutral
# 696  25-11-2022           Fri       World Cup     Group stage         Neutral
# 697  25-11-2022           Fri       World Cup     Group stage         Neutral
# 698  25-11-2022           Fri       World Cup     Group stage         Neutral
# 699  25-11-2022           Fri       World Cup     Group stage         Neutral
#
# ...

# %%
data.columns
# Out:
# Index(['Date', 'Defensive Day', 'Defensive Comp', 'Defensive Round',
#        'Defensive Venue', 'Defensive Result', 'Defensive Squad',
#        'Defensive Opponent', 'Defensive Start', 'Defensive Pos',
#        'Defensive Min', 'Defensive Tkl', 'Defensive TklW', 'Defensive Def 3rd',
#        'Defensive Mid 3rd', 'Defensive Att 3rd', 'Defensive Tkl.1',
#        'Defensive Att', 'Defensive Tkl%', 'Defensive Past', 'Defensive Blocks',
#        'Defensive Sh', 'Defensive Pass', 'Defensive Int', 'Defensive Tkl+Int',
#        'Defensive Clr', 'Defensive Err', 'Defensive Match Report'],
#       dtype='object')

# %%
list_1 = data["Date"].to_list()

# %%
list_2 = data["Defensive Tkl"].to_list()

# %%
list_3 = data["Defensive TklW"].to_list()

# %%
list_4 = data["Defensive Att"].to_list()

# %%
list_5 = data["Defensive Tkl%"].to_list()

# %%
list_6 = data["Defensive Past"].to_list()

# %%
list_7 = data["Defensive Blocks"].to_list()

# %%
list_8 = data["Defensive Sh"].to_list()

# %%
list_9 = data["Defensive Pass"].to_list()

# %%
list_10 = data["Defensive Int"].to_list()

# %%
list_11 = data["Defensive Tkl+Int"].to_list()

# %%
list_12 = data["Defensive Clr"].to_list()

# %%
list_13 = data["Defensive Err"].to_list()

# %%
from itertools import zip_longest

# %%
final_mapping = dict(zip(list_1,map(list,zip_longest(list_2,list_3,list_4,list_5,list_6,list_7,list_8,list_9,list_10,list_11,list_12,list_13))))

# %%
dictionary = dict(zip(data["Date"],data["Defensive Err"]))

# %%
df["Defensive Err"] = df.Date.map(dictionary)

# %%
df
# Out:
#             Date  Day            Comp           Round    Venue Result  \
# 0     28-05-2018  Mon  Friendlies (M)  Friendlies (M)     Away  D 0–0
# 1     28-05-2018  Mon  Friendlies (M)  Friendlies (M)     Away  D 0–0
# 2     28-05-2018  Mon  Friendlies (M)  Friendlies (M)     Away  D 0–0
# 3     28-05-2018  Mon  Friendlies (M)  Friendlies (M)     Away  D 0–0
# 4     28-05-2018  Mon  Friendlies (M)  Friendlies (M)     Away  D 0–0
# ...          ...  ...             ...             ...      ...    ...
# 1706  21-11-2022  Mon       World Cup     Group stage  Neutral  D 1–1
# 1707  21-11-2022  Mon       World Cup     Group stage  Neutral  D 1–1
# 1708  21-11-2022  Mon       World Cup     Group stage  Neutral  D 1–1
# 1709  21-11-2022  Mon       World Cup     Group stage  Neutral  D 1–1
# 1710  21-11-2022  Mon       World Cup     Group stage  Neutral  D 1–1
#
#           Squad          Opponent Start                                  Pos  \
# ...

# %%
df.to_csv("wales.csv",index=False)

# %%
df = pd.read_csv("wales.csv")

# %%
df
# Out:
#             Date  Day            Comp           Round    Venue Result  \
# 0     28-05-2018  Mon  Friendlies (M)  Friendlies (M)     Away  D 0–0
# 1     28-05-2018  Mon  Friendlies (M)  Friendlies (M)     Away  D 0–0
# 2     28-05-2018  Mon  Friendlies (M)  Friendlies (M)     Away  D 0–0
# 3     28-05-2018  Mon  Friendlies (M)  Friendlies (M)     Away  D 0–0
# 4     28-05-2018  Mon  Friendlies (M)  Friendlies (M)     Away  D 0–0
# ...          ...  ...             ...             ...      ...    ...
# 1706  21-11-2022  Mon       World Cup     Group stage  Neutral  D 1–1
# 1707  21-11-2022  Mon       World Cup     Group stage  Neutral  D 1–1
# 1708  21-11-2022  Mon       World Cup     Group stage  Neutral  D 1–1
# 1709  21-11-2022  Mon       World Cup     Group stage  Neutral  D 1–1
# 1710  21-11-2022  Mon       World Cup     Group stage  Neutral  D 1–1
#
#           Squad          Opponent Start                                  Pos  \
# ...
