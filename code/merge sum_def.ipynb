# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("Australia_summary.csv")
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 df=pd.read_csv("Australia_summary.csv")
#       2 df
#
# NameError: name 'pd' is not defined

# %%
data=pd.read_csv("Australia_defensive.csv")
data
# Out:
#            Date Defensive Day  Defensive Comp Defensive Round Defensive Venue  \
# 0    2014-04-09           Thu  Friendlies (M)  Friendlies (M)            Away
# 1    2014-04-09           Thu  Friendlies (M)  Friendlies (M)            Away
# 2    2014-05-03           Wed  Friendlies (M)  Friendlies (M)         Neutral
# 3    2014-05-26           Mon  Friendlies (M)  Friendlies (M)            Home
# 4    2014-06-06           Fri  Friendlies (M)  Friendlies (M)            Away
# ..          ...           ...             ...             ...             ...
# 544         NaN           NaN             NaN             NaN             NaN
# 545         NaN           NaN             NaN             NaN             NaN
# 546         NaN           NaN             NaN             NaN             NaN
# 547         NaN           NaN             NaN             NaN             NaN
# 548         NaN           NaN             NaN             NaN             NaN
#
# ...

# %%
df["Date"] = pd.to_datetime(df["Date"])
# Out:
# C:\Users\Admin-Pc\AppData\Local\Temp\ipykernel_9452\936118274.py:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])

# %%
data["Date"] = pd.to_datetime(data["Date"])

# %%
pd.merge(df,data,on = "Date",how = "left")
# Out:
#             Date  Day            Comp           Round    Venue Result  \
# 0     2018-03-23  Fri  Friendlies (M)  Friendlies (M)     Away  L 1–4
# 1     2018-03-23  Fri  Friendlies (M)  Friendlies (M)     Away  L 1–4
# 2     2018-03-23  Fri  Friendlies (M)  Friendlies (M)     Away  L 1–4
# 3     2018-03-23  Fri  Friendlies (M)  Friendlies (M)     Away  L 1–4
# 4     2018-03-23  Fri  Friendlies (M)  Friendlies (M)     Away  L 1–4
# ...          ...  ...             ...             ...      ...    ...
# 12934 2016-06-09  Tue             WCQ     Third round     Away  W 1–0
# 12935 2017-09-11  Thu  Friendlies (M)  Friendlies (M)     Home  L 0–1
# 12936 2014-05-03  Wed  Friendlies (M)  Friendlies (M)  Neutral  L 3–4
# 12937 2014-05-03  Wed  Friendlies (M)  Friendlies (M)  Neutral  L 3–4
# 12938 2014-05-03  Wed  Friendlies (M)  Friendlies (M)  Neutral  L 3–4
#
#               Squad        Opponent Start  Pos  ... Defensive Tkl%  \
# ...

# %%
data.columns

# %%
df.columns
