# %%
import pandas as pd

# %%
df = pd.read_csv("agentina.csv")
df1 = pd.read_csv("australia.csv")
df2 = pd.read_csv("costa rica.csv")
df3 = pd.read_csv("denmark.csv")
df4 = pd.read_csv("england.csv")
df5 = pd.read_csv("france.csv")
df6 = pd.read_csv("iran.csv")
df7 = pd.read_csv("maxico.csv")
df8 = pd.read_csv("netherlands.csv")
df9 = pd.read_csv("poland.csv")
df10 = pd.read_csv("saudi arabia.csv")
df11 = pd.read_csv("senegal.csv")
df12 = pd.read_csv("spain.csv")
df13 = pd.read_csv("tunisia.csv")
df14 = pd.read_csv("usa.csv")
df15 = pd.read_csv("wales.csv")

# %%
df.columns
# Out:
# Index(['Date', 'Day', 'Comp', 'Round', 'Venue', 'Result', 'Squad', 'Opponent',
#        'Start', 'Pos', 'Min', 'Gls', 'Ast', 'PK', 'PKatt', 'Sh', 'SoT', 'CrdY',
#        'CrdR', 'Touches', 'Tkl', 'Int', 'Blocks', 'xG', 'npxG', 'xAG', 'SCA',
#        'GCA', 'Cmp', 'Att', 'Cmp%', 'Prog', 'Succ', 'Att.1', 'Match Report',
#        'Fls', 'Fld', 'Off', 'Crs', 'TklW', 'OG', 'PKwon', 'PKcon',
#        'Defensive Tkl', 'Defensive TklW', 'Defensive Att', 'Defensive Tkl%',
#        'Defensive Past', 'Defensive Blocks', 'Defensive Sh', 'Defensive Pass',
#        'Defensive Int', 'Defensive Tkl+Int', 'Defensive Clr', 'Defensive Err'],
#       dtype='object')

# %%
frames = [df,df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15]

# %%
data=pd.concat(frames)

# %%
data.to_csv("worldcupdata.csv",index=False)

# %%
data = pd.read_csv("worldcupdata.csv")

# %%
data
# Out:
#              Date  Day            Comp           Round    Venue Result  \
# 0      23-03-2018  Fri  Friendlies (M)  Friendlies (M)     Home  W 2–0
# 1      23-03-2018  Fri  Friendlies (M)  Friendlies (M)     Home  W 2–0
# 2      23-03-2018  Fri  Friendlies (M)  Friendlies (M)     Home  W 2–0
# 3      23-03-2018  Fri  Friendlies (M)  Friendlies (M)     Home  W 2–0
# 4      23-03-2018  Fri  Friendlies (M)  Friendlies (M)     Home  W 2–0
# ...           ...  ...             ...             ...      ...    ...
# 12250  21-11-2022  Mon       World Cup     Group stage  Neutral  D 1–1
# 12251  21-11-2022  Mon       World Cup     Group stage  Neutral  D 1–1
# 12252  21-11-2022  Mon       World Cup     Group stage  Neutral  D 1–1
# 12253  21-11-2022  Mon       World Cup     Group stage  Neutral  D 1–1
# 12254  21-11-2022  Mon       World Cup     Group stage  Neutral  D 1–1
#
#               Squad          Opponent Start  \
# 0      ar Argentina          it Italy     Y
# ...

# %%
result = pd.concat(frames,ignore_index=True)

# %%
df = result.copy()

# %%
df
# Out:
#             Date  Day                 Comp           Round    Venue Result  \
# 0     11-11-2016  Fri                  WCQ     First round     Home  W 2–1
# 1     15-11-2016  Tue       Friendlies (M)  Friendlies (M)     Home  D 0–0
# 2     25-03-2017  Sat                  WCQ     First round     Away  W 3–1
# 3     28-03-2017  Tue       Friendlies (M)  Friendlies (M)     Home  L 0–2
# 4     02-06-2017  Fri       Friendlies (M)  Friendlies (M)     Home  W 5–0
# ...          ...  ...                  ...             ...      ...    ...
# 1198         NaN  NaN                  NaN             NaN      NaN    NaN
# 1199  22-09-2022  Thu  UEFA Nations League        League A     Home  W 2–0
# 1200  25-09-2022  Sun  UEFA Nations League        League A     Away  L 0–2
# 1201  22-11-2022  Tue            World Cup     Group stage  Neutral  W 4–1
# 1202         NaN  NaN                  NaN             NaN      NaN    NaN
#
# ...

# %%
df.columns
# Out:
# Index(['Date', 'Day', 'Comp', 'Round', 'Venue', 'Result', 'Squad', 'Opponent',
#        'Start', 'Pos', 'Min', 'Gls', 'Ast', 'PK', 'PKatt', 'Sh', 'SoT', 'CrdY',
#        'CrdR', 'Touches', 'Tkl', 'Int', 'Blocks', 'xG', 'npxG', 'xAG', 'SCA',
#        'GCA', 'Cmp', 'Att', 'Cmp%', 'Prog', 'Succ', 'Att.1', 'Match Report',
#        'Fls', 'Fld', 'Off', 'Crs', 'TklW', 'OG', 'PKwon', 'PKcon'],
#       dtype='object')
