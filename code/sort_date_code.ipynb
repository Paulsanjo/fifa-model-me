# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("tunisia_sum.csv")
df
# Out:
#             Date  Day                                 Comp           Round  \
# 0     20-11-2018  Tue                       Friendlies (M)  Friendlies (M)
# 1            NaN  NaN                                  NaN             NaN
# 2     25-03-2021  Thu  Africa Cup of Nations qualification     Group stage
# 3     28-03-2021  Sun  Africa Cup of Nations qualification     Group stage
# 4     05-06-2021  Sat                       Friendlies (M)  Friendlies (M)
# ...          ...  ...                                  ...             ...
# 1019  29-03-2022  Tue                                  WCQ     Third round
# 1020  02-06-2022  Thu  Africa Cup of Nations qualification     Group stage
# 1021         NaN  NaN                                  NaN             NaN
# 1022  27-09-2022  Tue                       Friendlies (M)  Friendlies (M)
# 1023  22-11-2022  Tue                            World Cup     Group stage
#
#         Venue Result       Squad        Opponent Start  \
# ...

# %%
df["Date"] = pd.to_datetime(df["Date"])
# Out:
# C:\Users\Admin-Pc\AppData\Local\Temp\ipykernel_8328\936118274.py:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])

# %%
df = df.sort_values(by = "Date",ascending=True)
df
# Out:
#            Date  Day                   Comp        Round Venue Result  \
# 936  2010-01-13  Wed  Africa Cup of Nations  Group stage  Away  D 1–1
# 937  2010-01-17  Sun  Africa Cup of Nations  Group stage  Away  D 0–0
# 183  2010-01-17  Sun  Africa Cup of Nations  Group stage  Away  D 0–0
# 938  2010-01-21  Thu  Africa Cup of Nations  Group stage  Away  D 2–2
# 184  2010-01-21  Thu  Africa Cup of Nations  Group stage  Away  D 2–2
# ...         ...  ...                    ...          ...   ...    ...
# 984         NaT  NaN                    NaN          NaN   NaN    NaN
# 999         NaT  NaN                    NaN          NaN   NaN    NaN
# 1009        NaT  NaN                    NaN          NaN   NaN    NaN
# 1013        NaT  NaN                    NaN          NaN   NaN    NaN
# 1021        NaT  NaN                    NaN          NaN   NaN    NaN
#
#            Squad     Opponent Start                                  Pos  ...  \
# ...

# %%
df.to_csv("tunisia_sum.csv",index=False)
